# %%
import os
import pandas as pd

# %%
cwd = os.getcwd() #current working directory
BASE_DIR = os.path.dirname(cwd)
data_dir = os.path.join(BASE_DIR, 'data')
cache_dir = os.path.join(BASE_DIR, 'cache')
working_file = os.path.join(cache_dir, 'movies-boxoffice-dataset.csv')
os.makedirs(cache_dir, exist_ok = True)

# %%
df = pd.read_csv(working_file)
df.head()
# Out:
#    Rank                                 Release Group       Worldwide  \
# 0     1                                   Toy Story 3  $1,066,969,703
# 1     2                           Alice in Wonderland  $1,025,467,110
# 2     3  Harry Potter and the Deathly Hallows: Part 1    $976,536,918
# 3     4                                     Inception    $826,137,188
# 4     5                           Shrek Forever After    $752,600,867
#
#        Domestic      %       Foreign    %.1  filename  year
# 0  $415,004,880  38.9%  $651,964,823  61.1%  2010.csv  2010
# 1  $334,191,110  32.6%  $691,276,000  67.4%  2010.csv  2010
# 2  $295,983,305  30.3%  $680,553,613  69.7%  2010.csv  2010
# 3  $292,576,195  35.4%  $533,560,993  64.6%  2010.csv  2010
# 4  $238,736,787  31.7%  $513,864,080  68.3%  2010.csv  2010

# %%
df['Rank'] = -1 # ranks are not set yet

# %%
df['Domestic %'] = df['%'] # we're making new columns here and not assigning one col's values to another
df['Foreign %'] = df['%.1']

# %%
df.drop(columns = ['%', '%.1'], inplace = True) #(inplace = True) as we want to make changes to current dataframe
# df.drop(['%', '%.1'], axis = 1)

# %%
df.head(n=1200)
# Out:
#       Rank                                 Release Group       Worldwide  \
# 0       -1                                   Toy Story 3  $1,066,969,703
# 1       -1                           Alice in Wonderland  $1,025,467,110
# 2       -1  Harry Potter and the Deathly Hallows: Part 1    $976,536,918
# 3       -1                                     Inception    $826,137,188
# 4       -1                           Shrek Forever After    $752,600,867
# ...    ...                                           ...             ...
# 1195    -1                                Les Misérables    $441,809,770
# 1196    -1                              Django Unchained    $425,368,238
# 1197    -1                                    Prometheus    $403,354,469
# 1198    -1                   Snow White and the Huntsman    $396,592,829
# 1199    -1                                       Taken 2    $376,141,306
#
#           Domestic       Foreign  filename  year Domestic % Foreign %
# 0     $415,004,880  $651,964,823  2010.csv  2010      38.9%     61.1%
# 1     $334,191,110  $691,276,000  2010.csv  2010      32.6%     67.4%
# 2     $295,983,305  $680,553,613  2010.csv  2010      30.3%     69.7%
# 3     $292,576,195  $533,560,993  2010.csv  2010      35.4%     64.6%
# 4     $238,736,787  $513,864,080  2010.csv  2010      31.7%     68.3%
# ...            ...           ...       ...   ...        ...       ...
# 1195  $148,809,770  $293,000,000  2012.csv  2012      33.7%     66.3%
# 1196  $162,805,434  $262,562,804  2012.csv  2012      38.3%     61.7%
# 1197  $126,477,084  $276,877,385  2012.csv  2012      31.4%     68.6%
# 1198  $155,332,381  $241,260,448  2012.csv  2012      39.2%     60.8%
# 1199  $139,854,287  $236,287,019  2012.csv  2012      37.2%     62.8%
#
# [1200 rows x 9 columns]

# %%
df['Worldwide'] = df['Worldwide'].replace("$", "").replace(",","") # <-- this will not work

# %%
cols_to_clean = ["Worldwide", "Domestic", "Foreign"]

def currency_str_to_int(current_val):
    currency_val = current_val.replace("$", "").replace(",","")
    return currency_val
    
    

def clean_col(row):
    """
    row = Pandas Series (nomenclature)
    dataframe = collection of Pandas Series
    """
#     print(row)
    
    for c in cols_to_clean:
        row[c] = currency_str_to_int(row[c])
    return row
    
    
    
df_cleaned = df.apply(clean_col, axis = 1)
df_cleaned.head()
# Out:
#    Rank                                 Release Group   Worldwide   Domestic  \
# 0    -1                                   Toy Story 3  1066969703  415004880
# 1    -1                           Alice in Wonderland  1025467110  334191110
# 2    -1  Harry Potter and the Deathly Hallows: Part 1   976536918  295983305
# 3    -1                                     Inception   826137188  292576195
# 4    -1                           Shrek Forever After   752600867  238736787
#
#      Foreign  filename  year Domestic % Foreign %
# 0  651964823  2010.csv  2010      38.9%     61.1%
# 1  691276000  2010.csv  2010      32.6%     67.4%
# 2  680553613  2010.csv  2010      30.3%     69.7%
# 3  533560993  2010.csv  2010      35.4%     64.6%
# 4  513864080  2010.csv  2010      31.7%     68.3%
